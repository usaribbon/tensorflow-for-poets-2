# %% [markdown]
# # かぶと
#
# ## スクリプト実行環境に移動

# %%
cd /root/userspace/team11/tensorflow-for-poets-2/
# Out:
# /root/userspace/team11/tensorflow-for-poets-2

# %% [markdown]
# ## かぶと画像をモデルに学習させる
# すでに学習済なので、追加画像がない場合は再学習不要

# %%
# !python3 scripts/retrain.py --output_graph=tf_files/retrained_graph.pb --output_labels=tf_files/retrained_labels.txt --image_dir=tf_files/kabuto
# Out:
# INFO:tensorflow:Looking for images in '01'
# INFO:tensorflow:Looking for images in '02'
# INFO:tensorflow:Looking for images in '03'
# INFO:tensorflow:Looking for images in '04'
# INFO:tensorflow:Looking for images in '05'
# INFO:tensorflow:Looking for images in '06'
# INFO:tensorflow:Looking for images in '07'
# INFO:tensorflow:Looking for images in '08'
# INFO:tensorflow:Looking for images in '09'
# INFO:tensorflow:Looking for images in '10'
# WARNING:tensorflow:WARNING: Folder has less than 20 images, which may cause issues.
# INFO:tensorflow:Looking for images in '11'
# 2019-03-16 02:39:13.252024: I tensorflow/core/platform/cpu_feature_guard.cc:137] Your CPU supports instructions that this TensorFlow binary was not compiled to use: SSE4.1 SSE4.2 AVX
# 2019-03-16 02:39:13.307353: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:892] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# ...

# %% [markdown]
# ## 画像を次に折るべきステップを動画で紹介
# 例）08ステップ目の画像→次の折り方動画を再生

# %%
# !python3 scripts/label_image.py --image tf_files/answer/08_answer.jpeg
# Out:
# 2019-03-16 04:16:54.453084: I tensorflow/core/platform/cpu_feature_guard.cc:137] Your CPU supports instructions that this TensorFlow binary was not compiled to use: SSE4.1 SSE4.2 AVX
# 2019-03-16 04:16:54.514099: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:892] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-03-16 04:16:54.514389: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1030] Found device 0 with properties:
# name: GRID K520 major: 3 minor: 0 memoryClockRate(GHz): 0.797
# pciBusID: 0000:00:03.0
# totalMemory: 3.94GiB freeMemory: 3.90GiB
# 2019-03-16 04:16:54.514431: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1120] Creating TensorFlow device (/device:GPU:0) -> (device: 0, name: GRID K520, pci bus id: 0000:00:03.0, compute capability: 3.0)
# ...
